# %%
import requests
import math
from datetime import datetime
import time

def fetch_iss_data():
    url = "https://api.wheretheiss.at/v1/satellites/25544"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Failed to fetch ISS data.")
        return None

def format_latitude_longitude(latitude, longitude):
    lat_direction = "N" if latitude >= 0 else "S"
    lon_direction = "E" if longitude >= 0 else "W"
    return "{:.1f}° {}".format(round(abs(latitude), 1), lat_direction), "{:.1f}° {}".format(round(abs(longitude), 1), lon_direction)

def calculate_orbital_period(altitude, velocity):
    # Average radius of Earth in kilometers
    R_earth = 6371
    
    # Average altitude of the ISS orbit in kilometers
    altitude_km = altitude
    
    # Radius of the orbit
    r = R_earth + altitude_km
    
    # Orbital velocity in km/s
    v = velocity / 3600  # Convert velocity from km/h to km/s
    
    # Orbital period using Kepler's third law
    T = (2 * math.pi * r) / v
    return round(T / 60, 1)  # Convert seconds to minutes and round to 1 decimal place

# Function to get current date and time in GMT
def get_current_time_gmt():
    return datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S GMT')

# Fetch and display ISS data every 20 seconds
while True:
    iss_data = fetch_iss_data()
    if iss_data:
        latitude, longitude = format_latitude_longitude(iss_data['latitude'], iss_data['longitude'])
        print("ISS Latitude:", latitude)
        print("ISS Longitude:", longitude)
        if 'velocity' in iss_data:
            print("ISS Speed:", round(iss_data['velocity'], 1), "km/h")
        else:
            print("ISS speed data not available in the response.")
        if 'altitude' in iss_data:
            altitude_km = iss_data['altitude']
            print("ISS Altitude:", round(altitude_km, 1), "km")
            if 'velocity' in iss_data:
                orbital_period = calculate_orbital_period(altitude_km, iss_data['velocity'])
                print("Estimated Orbital Period:", orbital_period, "minutes")
        else:
            print("ISS altitude data not available in the response.")
        print("Date and Time (GMT):", get_current_time_gmt())
    time.sleep(10)  # Wait for 20 seconds before fetching data again
# Out:
# ISS Latitude: 13.2° S
# ISS Longitude: 46.0° W
# ISS Speed: 27579.8 km/h
# ISS Altitude: 418.8 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:55:38 GMT
# ISS Latitude: 12.6° S
# ISS Longitude: 45.6° W
# ISS Speed: 27580.4 km/h
# ISS Altitude: 418.6 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:55:50 GMT
# ISS Latitude: 12.0° S
# ISS Longitude: 45.1° W
# ISS Speed: 27581.0 km/h
# ISS Altitude: 418.4 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:56:03 GMT
# ISS Latitude: 11.3° S
# ISS Longitude: 44.6° W
# ISS Speed: 27581.7 km/h
# ISS Altitude: 418.2 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:56:15 GMT
# ISS Latitude: 10.7° S
# ISS Longitude: 44.2° W
# ISS Speed: 27582.2 km/h
# ISS Altitude: 418.0 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:56:27 GMT
# ISS Latitude: 10.2° S
# ISS Longitude: 43.8° W
# ISS Speed: 27582.8 km/h
# ISS Altitude: 417.8 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:56:38 GMT
# ISS Latitude: 9.6° S
# ISS Longitude: 43.3° W
# ISS Speed: 27583.3 km/h
# ISS Altitude: 417.6 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:56:50 GMT
# ISS Latitude: 9.0° S
# ISS Longitude: 42.9° W
# ISS Speed: 27583.9 km/h
# ISS Altitude: 417.5 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:57:02 GMT
# ISS Latitude: 8.4° S
# ISS Longitude: 42.5° W
# ISS Speed: 27584.5 km/h
# ISS Altitude: 417.3 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:57:14 GMT
# ISS Latitude: 7.8° S
# ISS Longitude: 42.1° W
# ISS Speed: 27585.0 km/h
# ISS Altitude: 417.1 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:57:25 GMT
# ISS Latitude: 7.2° S
# ISS Longitude: 41.6° W
# ISS Speed: 27585.5 km/h
# ISS Altitude: 417.0 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:57:37 GMT
# ISS Latitude: 6.6° S
# ISS Longitude: 41.2° W
# ISS Speed: 27586.1 km/h
# ISS Altitude: 416.8 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:57:49 GMT
# ISS Latitude: 6.0° S
# ISS Longitude: 40.7° W
# ISS Speed: 27586.6 km/h
# ISS Altitude: 416.7 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:58:01 GMT
# ISS Latitude: 5.4° S
# ISS Longitude: 40.3° W
# ISS Speed: 27587.1 km/h
# ISS Altitude: 416.5 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:58:12 GMT
# ISS Latitude: 4.8° S
# ISS Longitude: 39.9° W
# ISS Speed: 27587.6 km/h
# ISS Altitude: 416.4 km
# Estimated Orbital Period: 92.8 minutes
# Date and Time (GMT): 2024-04-09 08:58:24 GMT
# ISS Latitude: 4.2° S
# ISS Longitude: 39.5° W
# ISS Speed: 27588.1 km/h
# ISS Altitude: 416.2 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 08:58:36 GMT
# ISS Latitude: 3.6° S
# ISS Longitude: 39.0° W
# ISS Speed: 27588.6 km/h
# ISS Altitude: 416.1 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 08:58:48 GMT
# ISS Latitude: 3.0° S
# ISS Longitude: 38.6° W
# ISS Speed: 27589.1 km/h
# ISS Altitude: 415.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 08:59:00 GMT
# ISS Latitude: 2.4° S
# ISS Longitude: 38.2° W
# ISS Speed: 27589.6 km/h
# ISS Altitude: 415.8 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 08:59:12 GMT
# ISS Latitude: 1.7° S
# ISS Longitude: 37.7° W
# ISS Speed: 27590.1 km/h
# ISS Altitude: 415.7 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 08:59:24 GMT
# ISS Latitude: 1.1° S
# ISS Longitude: 37.3° W
# ISS Speed: 27590.6 km/h
# ISS Altitude: 415.5 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 08:59:36 GMT
# ISS Latitude: 0.5° S
# ISS Longitude: 36.9° W
# ISS Speed: 27591.1 km/h
# ISS Altitude: 415.4 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 08:59:48 GMT
# ISS Latitude: 0.1° N
# ISS Longitude: 36.4° W
# ISS Speed: 27591.5 km/h
# ISS Altitude: 415.3 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:00:01 GMT
# ISS Latitude: 0.7° N
# ISS Longitude: 36.0° W
# ISS Speed: 27592.0 km/h
# ISS Altitude: 415.2 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:00:13 GMT
# ISS Latitude: 1.3° N
# ISS Longitude: 35.6° W
# ISS Speed: 27592.5 km/h
# ISS Altitude: 415.1 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:00:24 GMT
# ISS Latitude: 1.9° N
# ISS Longitude: 35.2° W
# ISS Speed: 27592.9 km/h
# ISS Altitude: 415.0 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:00:36 GMT
# ISS Latitude: 2.5° N
# ISS Longitude: 34.7° W
# ISS Speed: 27593.3 km/h
# ISS Altitude: 414.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:00:48 GMT
# ISS Latitude: 3.1° N
# ISS Longitude: 34.3° W
# ISS Speed: 27593.8 km/h
# ISS Altitude: 414.8 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:01:00 GMT
# ISS Latitude: 3.8° N
# ISS Longitude: 33.9° W
# ISS Speed: 27594.2 km/h
# ISS Altitude: 414.7 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:01:12 GMT
# ISS Latitude: 4.4° N
# ISS Longitude: 33.4° W
# ISS Speed: 27594.6 km/h
# ISS Altitude: 414.6 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:01:24 GMT
# ISS Latitude: 4.9° N
# ISS Longitude: 33.0° W
# ISS Speed: 27595.0 km/h
# ISS Altitude: 414.6 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:01:35 GMT
# ISS Latitude: 5.5° N
# ISS Longitude: 32.6° W
# ISS Speed: 27595.4 km/h
# ISS Altitude: 414.5 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:01:47 GMT
# ISS Latitude: 6.2° N
# ISS Longitude: 32.2° W
# ISS Speed: 27595.8 km/h
# ISS Altitude: 414.4 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:01:59 GMT
# ISS Latitude: 6.8° N
# ISS Longitude: 31.7° W
# ISS Speed: 27596.1 km/h
# ISS Altitude: 414.3 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:02:11 GMT
# ISS Latitude: 7.4° N
# ISS Longitude: 31.3° W
# ISS Speed: 27596.5 km/h
# ISS Altitude: 414.3 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:02:23 GMT
# ISS Latitude: 8.0° N
# ISS Longitude: 30.8° W
# ISS Speed: 27596.9 km/h
# ISS Altitude: 414.2 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:02:35 GMT
# ISS Latitude: 8.5° N
# ISS Longitude: 30.4° W
# ISS Speed: 27597.2 km/h
# ISS Altitude: 414.2 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:02:46 GMT
# ISS Latitude: 9.1° N
# ISS Longitude: 30.0° W
# ISS Speed: 27597.6 km/h
# ISS Altitude: 414.1 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:02:58 GMT
# ISS Latitude: 9.8° N
# ISS Longitude: 29.5° W
# ISS Speed: 27597.9 km/h
# ISS Altitude: 414.1 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:03:10 GMT
# ISS Latitude: 10.4° N
# ISS Longitude: 29.1° W
# ISS Speed: 27598.2 km/h
# ISS Altitude: 414.0 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:03:22 GMT
# ISS Latitude: 11.0° N
# ISS Longitude: 28.6° W
# ISS Speed: 27598.5 km/h
# ISS Altitude: 414.0 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:03:34 GMT
# ISS Latitude: 11.6° N
# ISS Longitude: 28.2° W
# ISS Speed: 27598.9 km/h
# ISS Altitude: 414.0 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:03:46 GMT
# ISS Latitude: 12.1° N
# ISS Longitude: 27.8° W
# ISS Speed: 27599.1 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:03:57 GMT
# ISS Latitude: 12.7° N
# ISS Longitude: 27.3° W
# ISS Speed: 27599.4 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:04:09 GMT
# ISS Latitude: 13.3° N
# ISS Longitude: 26.9° W
# ISS Speed: 27599.7 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:04:21 GMT
# ISS Latitude: 13.9° N
# ISS Longitude: 26.4° W
# ISS Speed: 27600.0 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:04:33 GMT
# ISS Latitude: 14.5° N
# ISS Longitude: 26.0° W
# ISS Speed: 27600.3 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:04:45 GMT
# ISS Latitude: 15.1° N
# ISS Longitude: 25.5° W
# ISS Speed: 27600.5 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:04:56 GMT
# ISS Latitude: 15.7° N
# ISS Longitude: 25.1° W
# ISS Speed: 27600.8 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:05:08 GMT
# ISS Latitude: 16.2° N
# ISS Longitude: 24.6° W
# ISS Speed: 27601.0 km/h
# ISS Altitude: 413.9 km
# Estimated Orbital Period: 92.7 minutes
# Date and Time (GMT): 2024-04-09 09:05:19 GMT
